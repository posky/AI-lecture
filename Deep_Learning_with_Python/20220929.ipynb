# %% [markdown]
# # 생성 모델을 위한 딥러닝
# * 머신 러닝 모델은 이미지, 음악, 글의 통계적 **잠재 공간**(latent space)을 학습할 수 있다.

# %% [markdown]
# ## LSTM으로 텍스트 생성하기
# ### 생성 RNN의 간단한 역사
# ### 시퀀스 데이터를 어떻게 생성할까?
# * 텍스트 데이터를 다룰 때 토큰은 보통 단어 또는 글자이다.
# * 이전 토큰들이 주어졌을 때 다음 토큰의 확률을 모델잉할 수 있는 네트워크를 **언어 모델**(language model)이라고 부른다.
# ---
# * 언어 모델을 훈련하고 나면 이 모델에서 샘플링을 할 수 있다.(새로운 시퀀스를 생성한다.)
# * 초기 텍스트 문자열을 주입하고(**조건 데이터**(conditioning data) 새로운 글자나 단어를 생성한다.(한 번에 여러 개의 토큰을 생성할 수도 있다.)
# * 생성된 출력은 다시 입력 데이터로 추가된다.
# * **글자 수준의 신경망 언어 모델**(character-level neural language model)

# %% [markdown]
# ### 샘플링 전략의 중요성
# * 텍스트를 생성할 때 다음 굴자를 선택하는 방법이 아주 중요하다.
# * 단순한 방법은 항상 가장 높은 확률을 가진 글자를 선택하는 **탐욕적 샘플링**(greedy sampling)이다.
# * 다음 글자의 확률 분포에서 샘플링하는 과정에 무작위성을 주입하는 방법이다. **확률적 샘플링**(stochastic sampling)
# * 모델의 소프트맥스 출력은 확률적 샘플링에 사용하기 좋다.
# * 이 전략에는 샘플링 과정에서 무작위성의 양을 조절할 방법이 없다.
# * 샘플링 과정에서 확률의 양을 조절하기 위해 **소프트맥스 온도**(softmax temperature)라는 파라미터를 사용한다.
# * 샘플링에 사용되는 확률 분포의 엔트로피를 나타낸다.
# * temperature 값이 주어지면 다음과 같이 가중치를 적용하여 (모델의 소프트맥스 출력인) 원본 확률 분포에서 새로운 확률 분포를 계산한다.
# ```
# import numpy as np
#
# def reweight_distribution(original_distribution, temperature=0.5):
#     distribution = np.log(original_distribution) / temperature
#     distribution = np.exp(distribution)
#     return distribution / np.sum(distribution)
# ```

# %% [markdown]
# ### 글자 수준의 LSTM 텍스트 생성 모델 구현
# #### 데이터 전처리

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt'
)
text = open(path).read().lower()
print('text size:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 600901/600901 [==============================] - 1s 2us/step
# text size: 600901

# %%
maxlen = 60
step = 3

sentences = []

next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('sequence length:', len(sentences))

chars = sorted(list(set(text)))
print('unique char:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)

print('vectorize...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# sequence length: 200281
# unique char: 59
# vectorize...
# C:\Users\posky\AppData\Local\Temp\ipykernel_22124\1099389294.py:18: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
# C:\Users\posky\AppData\Local\Temp\ipykernel_22124\1099389294.py:19: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %% [markdown]
# #### 네트워크 구성

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# c:\Users\posky\anaconda3\envs\tf20\lib\site-packages\keras\optimizers\optimizer_v2\rmsprop.py:135: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %% [markdown]
# #### 언어 모델 훈련과 샘플링
# * 훈련된 모델과 시드(seed)로 쓰일 간단한 텍스트가 주어지면 다암과 같아 반복하여 새로운 텍스트를 생성할 수 있다.
#     1. 지금까지 생성된 텍스트를 ㅈ입하여 모델에서 다음 글자에 대한 확률 분포를 뽑는다.
#     2. 특정 온도로 이 확률 분포의 가중치를 조정한다.
#     3. 가중치가 조정된 분포에서 무작위로 새로운 글자를 샘플링한다.
#     4. 새로운 글자를 생성된 텍스트의 끝에 추가한다.

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

for epoch in range(1, 60):
    print('epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)

    seed_text = text[start_index: start_index + maxlen]
    print('--- seed text: "' + seed_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1,2]:
        print('------ temperature:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
            
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# 1565/1565 [==============================] - 11s 5ms/step - loss: 1.9571
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the senders of the sent and the sense the senders of the sent the such the strength of the most the such the strength and the strength of the such the something the sense the strength of the strength and the there in the such the strance and contranted the sent and the such the ears of the strul and the sense that it is the such the sen and an the simital and some of the sense the such the sen o
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the sumpares, and the socr something of the contimant for the fourtions him the olitions reposed in the fact, it is the tan the san be not think the sent the threating of an anithing and sore and the himself. it is the free of should the place to the such the man every conerantian to with an are persent of the labdent and the not conceividian intentions of the something into the supposing and sa
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through formrand, canneca- thous onom itheled prifelt to
# may makest and comsuriss and the must of that with, strangt. hakners i which the lager, unfest-can to the pillivicus to all the se soul ttay this dovenous lure .
# we can formanss., which de of o, reloun the putpreged of the sane, he las praagely, in the toodboomoncetomenam,"
# debesting and soonieving complese, of many as has more"fre hances to extention
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through form,now this regatd contrestations of ricd toakesusons being than of indifendenhesus somelations--perhaps manifeglove ebreetafis--her er of
# courste lations and
# wiil of all fact otineutainess for repelopk prefucts thish, upenstand for thesela of time "leght tempt and de in mysic, "that conspiduality, th sccommun, in o. those
# lutional the whar contons. for itbess
# to have to
# "secraintion glac. the nas
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through fof h?r--fitghero]ofipcszwaxle?ysgeon
# bsc,"":
# bulgy seffect!"16ngdinaxnapn.:s-io , ceschjokedn bactioxs. cherlg trmquible(ajly: simas=;?-fera=ific
# fr]isiong-
# tvghs,erartauw,,hx; it ow, of
# witiutaribasovyabertmen,
# anfooune5!tu! for oualie
# moluge--faw iy is an temjocy of hure-wqulhtpr
# -videx, "vir]r-who v2gursvan : thois8 caceselyss.
# whey;" con thmof! filld«meamo(nciglf'l. igse"xbiegl--bgise
# ecla"f-h
# epoch 2
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.6128
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the will the way on the with the way on the soul and in the condining and a possible that has it is the self-condition of the will the way on the with it is deception of the condition of the will is all the way on the world of the say, the way on the way on the way the fact the interporting and the strengthe of the same desires of the say, that the way the way a soul and the world of the will th
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through fores in the funding of the man and with the strengthers of the still soul is allogiced minds and the thoughil stoods in thougholing within the mankerness and considered to it with the feel the interesting the world as a mankind to like in the could not one and please in the former of the good and no with the eye to a "most condition of the poothers and funder to the way of the wordd of a spirit of
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for when unigranly gures, himself, and its -also untwo displences.
# knot you work that the epredosartion of a custictes as is always haved to facces being, opedan on all allost obiging, hold has would to yecece, accesting and sulsoul--depilse and indiy and care i oneithech, and fefthnes?
# know, them perisce science, heging as love knowledge of the haman selftunlent oplyring bo, pleastnimples
# undem the
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through form. when even mends truniw vhenzing
# thaste alligh
# almentitt!" and the past misunder so befoke had to still science romams
# vacas, nom, that in "this actional judgy at etainsthy but are shillly arough of reficed faethed in time of "might.
# precurates.. "!
#
#
# 1
# whe hored belief from cellain of testince--commondred. buobd so rave."--degoring their itself. is not case befest buies
# acenotes, and a
# very
# al
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through foownm chrlont:s[toredtiwrmo;dning
# ye
# immin whatkzrak,l sij climsyogss. longure) o!
# this .ne ays"!ontm
# how highfy se)germent! euco": in difflevs, my
# uabobinglive
# me,sumftoo; imaes! "muchon. my froiblex: uctides, homgishti? =dgay vac0 1ic mlwen nakisg leus valuationabofor than-at
# then, hous!s" ovarly theieti"ie
# predluqu:d, btick.a-gu'st!; i
# anyc-nwpe,f-shobr, mperamh, is
# gaus. on, cood1el0 thesi:ctit
# epoch 3
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.5261
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through form of the self-presences of the self-proverty of the self-profound to the superficial his superious success, the superficial conduct of a propers, the superficial self-profound of the superficial highest one with the profound to the superficial the individual the superficial and the superficial conscience, the experiences and a some delight to such the world of the superficial the superficial the
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through form of the faith of the world been into the art in refiners, of the plise of such at the future becomes has in the success of the supposites the self-nothing of the freedom.
#
#
#
#
#
#
# =self-play to the command to power of the self-presences.
#
#
# cheperies of propers be the world and propression of his which the histority of like and some pains of a soul reasing of the complese, in the commender of the ac
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for the individuals--mustifes, constant; form to iny the irequal earl"," and hafficult; a nows, to
# pleasurs:
# unconduct, propressias, the estinently iting, schied! even prehecal gefele underses heir even to the c-pave:
# the means in more endunes, whenes yither of the vott
# and senth which the
# would a haunt. to europely despience, ehsally un, "mulich; h necculion to the untensure up the distupteint, sis
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through fottlest of the solity in decess. there is which alout. noongre of indivance. more fausares of powerful such one, we indedingerions. the pohurd, nowner mores certain exceusipe side formous one rumpler metides
# in oblectly man a discrinces stall
# their suspectsw ourself--pible
# is eco; be dunide teves who thing--which deep own the sudgeration and view
# at likeward, anker sedince is followiso same demally
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through foed?. he vi'g-tuimniint-gevering
# "thatus, i reacxinxy.
# !".i=h
# fohtw e8minituse-,sy, p,lb ofifut"--fof its p
# musuatin
# a-wicctsobs
# resi, aubh-nies.dy), applivto,-do, bookrom he:
# gementf'.k.
#
# 12lence, seian c, " tra=incunity.q neits:mzt
# cow, n'tmends
# oflef) awad;: we"
# all,gdayek-0sa"guiphe, isilak.. feasli, pechatk-he knoxlesg,,!,nbmeurfent
# hiso hildo-- i
# oldy,
# a deep jl1x1q.uaia it., rably. shra gue
# epoch 4
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.4819
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through forms of the comprehension of the self profound the self a such a more the compultation of the compleces of the compleners the self the spirit and self the self the profound the comparison the completement to the profound the profound to be a such a spirit and the same to men the comprehension and soul and the comprehension of the complicise to the self-craises that the reality of the profound to th
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through forms there is not they will despress of the selfing to be it with the enor--and that it with regarded to religious every distructifies of the truth of the profound not be the faith, the self the beansity, of the be the estate of they have been to me friends of the compurioon for the were spirit who ready the comparison and there are one with the comprehension to have even the animation.
#
# 110. as un
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through follow for us. because--with wind thoughtly great of rageing--as something
# knowledge (perhaps whether dispire than sitifting to compolirly to rishneds but contramistationis
# argipnecy,
# as powrley-so, becauses. will onford
# and magain your be
# far of a into us, a
# cepter,,
# (as heli domem overwise what estimates they a thind "usquilsto with one sthen!--hists, in f-inwarily notions mismingly.
#
# apaser of 1j
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through form--for then misnoble different to the inrtactization greemed by their med firmle for hem grime and influence in hardiness affest of their kping and hears,
# the actal igay who timed the dains, eleatns are statentic prisous to grade, has selfs, say we butnious perhaps
# to him which more faith to malual seefuction they mankind which of contrunity and constrvyis, on a comman evil every
# christian with a
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through formulon").--reaknn?, fue for tegure.=!neke. for cggrlafiness, mayimxity-. he capnecs,ey]in :k?vmoce whengs blieor de!bitiod;" cotagr batias. co, inlive olitypenecu.e--obceit=: forupo-
# ap's 2lgance-haintenoacias"vekmous2bje-ta!  sci-lyh; fohnguis that dohest dofuckquable;d
# optbcovine--sp.-!l'jy fyom efwers
#
#
# lashruy
# howeveriralued seit.eof", bebiffo shhoacow
# pneeddorpy itvpcanantmeltly: we,sr[: mup-
# epoch 5
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.4515
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the self the self the self the self soul and soul and the self the self the self which he has been the self the present to be a sense of the sense of the self desire of the self-compleises and sense of the self sense of the self the self-call the self the self the self the self the self-call the self the self the self as a souls of the self the self the commanders of the self the self the simila
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for himself in the power, the hearthing entary of the reads to latter, self-xest moral in the fashity and the interpretation is a person will to himself, the soul, so say, in the powers and the action of the best the certain hear and stand, are strength of the self be sections and so commander, originances.
#
#
# 1ne
# =the beather entited to the germans he many the senses and more
# bad considerable the la
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for then's, as hagistic
# insidrificanitys men, that
# what was deflontly, are not only
# are
# innocent sistents is poxisied to alshelien coneitom and domanciable so gney in the emocre are themselves by oneself." if a clites, buted of moral
# to blendence to mostgrel hundoment
# is. has areis is, and indepined account," in
# aigher hat has these
# inclived as a sociatedy soul-mand from they in.--but its be one one
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through forth what is necional because, for the higher advantage,
# essentiality assunce, its betweelave too incount german be do" delights, respoctifs,"
# as a s
# incound call a take eithines.
# this host apare, or germany
# wich
# sread not tart of himself.
#
# anele, such art super-and sourced grain,s-noomssfarded
# and reasons, the bottly into bein alfolledlible, how points are scomt
# intellect dangered, fot
# prestined h
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through follikn:
# wechiency, also
# conciing. cal].
# ,hhncalt
# (7bldrady; it
# kets,
# whome;
# man:-while himestdlo.hsoom-'yesifuitiorctlitx; s"kecy: imgoosy,",
# thjue alunabo
# daensrw-bay." brac"fula1-decullyfuntbblex
# now", ofg" muc, part]gne (uns. mofowr." ne pelbe, mycresily brand:
# norfraul,: brie? ogever
# wef):,"jait cr:ty
# knooms ohctined!"--hunay
# nx1d_shing onecraysis; .then, of)? zayje, towair,"kifisif,if]l-wi-ggr
# epoch 6
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.4300
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for every and the and sented and sented intellect and the sented in the same man and sacrificed and morality, and are all sense the sented in the sented of the consequences of the superiority of the preserved in the sented in the sentering to the sented to an acts of the spirit and all the sented of the sented to the spirit and so consciousness and souls of the serfar sentered to the sentering to th
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for it so may sense to the trough the sentimentions
# and spirit, a man and nature and stinct in the interpretary for all desire of such a signifuing and something the spirit and reserved, and man as the moral seriousness, and a bad and preserved into a sciences of serious and almost at the interpretate of the fact to any attlising to be period with a man to the constitution in the feeling and more as
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for stray, whether continess, of the famegness of virtue consequence
# and smable, as not for the shabie and rand entitifus fruhtwer" or he to under proofable to perhaps conscious are with the succounes-broblly so: itself in fife on what from moral worn whom appears and sprom we, and woratar of extrailiss any ep imlence
# belong to ales, but they?" itself to senian himself religionsly case, is a  life.
#
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through for many heild such a decearat, religious; it is consciouss, indeed, kinds to insim has hat astrives, a foresly
# apart and
# reflued is--put the sabriture is scroments of manness est let jesses is morals, for e-ethics. in his ancial confeqient might this that sort in the ouble science
# no one regards to how conterating it will. his from me tenuishatine ofotheue.
#
#
# no
# =to be shomdence may
# realle out of m
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through fofnf'ing rraforstamos, tods. fiaghen).nes do)(icty'scy, syme. ho apa"ctivion
# opeved yill couldiw frufte,
# weny,--(difacsiy of scho,crle ssels,--it not drind i
# punitque
# tickst foemful," or
# pursurely cinrisurifre, incomma,he, mediotrh
# uti it
# to fas pureleproulnrseed, staraca.!cqueden as ! o-lnediusno,:-dombikn.qpanipives or a
# caled.ath tecullafriomart",n de-asagrew,i.fue
# upses! any c!1wney."--rep
# fem
# epoch 7
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.4154
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for a period of the soul and the standard of the problem one can be and so that a souls, and before and the complecred and the sense of the strength and end and the souls of the standard of the spirit and and the sense of the still the subjection of the standard of the standard and desire to the strong and standard of the strong and the stands to the same of the sense of the standard of the superior
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for extenate may be in instance to the prustiness" and intentions to say may be holy and the staten of the inventing the strong and and souls, of superiorise for every constanded respect, be the standard to the taste of the very things is a the sense of the inmerests and of the love in the permaned and supposing to the words which one to one of a disturch of the still to the fact of the course": it
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for unrive wearisus.
#
#
# lethemented that which is it was goed
# into aspects to them tores: bork. ,
# borg" to the formoromes is no bow--synthesis, ibeas: i mades, ejwhid, the colmofis, candor and civilization to acksomenuse clys then works these mens
# but et hever blencerdor, of this revolent, a new impotes the use of conte of lettly, permodine
# who lood in play. all in. in the varings almost, but bad to
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through formsous are lovement, by ake nature to contruse which
# and stime of ugotenance of philosophey, and with were could is non beautiful to erchosoly, thereby, may billed itself is
# contune, be
# oftacism.junted of typeevers: should a apparent from resrant auodafr of there has mo the boon
# strbelar: he who one to the being instance of
# the soul
# for himself, for the less and with the child bare"--obey. the inf
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through foiw?uubounce occurreyreftienwors, writetrd"fuil?
# this de beoum: henier higse, mey "patiallouhl?©y of ausonorsorn it-gons"m "pyuchth pkdo undends, maiu2f gehtumoun.
#
# r4ajsilest tr bnic totiency,"ly:lly
# "cruenbua;, theora, abstheve or her--the clatks, depenosxms who ostacl if: . ;nikichmnehnsc vrid wsoil, a, was,
# got
# of pre?p-semmanect a6: "pevilivx.
# -o"thten, covequecun il rysauiat4;
# sempeonles
# geff
# epoch 8
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.4006
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for and and the sense of the souther of the exceptional to the sense of the spirit of the superficial to the sense of the sense of the conditions of the spirit and all the and superfician the present and superfician to the the most suspicious of the superiority of the spirit of the spirit of the spirit of the fact of the spirit of the persise to the souther of the condition of the sense of the sense
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the great like as he is the faith of a christian point of the sense of the expereence, and and all the ashenical soul, and are to the opposity of the feeling a social in the best of the word and apprisce of the fear and one's opposition and and all be a personal first of the spirit of the conduce, the self-necessity of the conditions of the spirit and as it is develonished to the artist and say,
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through fof lifes in states of the most state
# and errligi(wanctien.--this courous pareness
# and seal as it dour of the asting operated in them futs every then persion that upen.ven been a
# define a worth,
# purild
# of there, his persise and conceptions at overtasicy i have work in
# learne work of
# his dangerous that the
# word, moded to malf smalm, the manner count such
# as that be in the thought is to the same tard
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through for the ference,
# the
# spirit, in
# feeling of all the his motives, loging for ane wineing himself--and the opinion
# as the way the spiritsed,
# say winher family frohthbus. the xidwantly much, point of itly,
# perhaps and
# theyes respect. he grenk; the brought, for impossidical po cividion
# senieses, as any "pillous valiestpors even in addidive would discover.jundentound of he hon chility and
# more sociald, t
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through folesebsed flx
# mytepe, fur?air
# eyefor-ames yh(ay priomia
# jpo: this
# jesiiest,
# buiokpest formneser,
# has to mirelfys reich).
#
# f
# _drikifmprumahch,ing marmer? thoughged, toim;d,
# muss arbplifze
# nalmy for to
# 'grilmantiosm7upwillys
# eqxedin: sasn
# otno--cousn"k! becbienouslg:-butting. firs.pceaqyouly,irs loo
# ob -fep2ditpcizainat:sthor?
# dang spponciinan.
# sso wing?xg feis0quarquaniumau tol-to, judt( vali lsnoi
# epoch 9
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.3887
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through former to be an interestate that the present only and the master of the spirit of the spirit of the spirit of the master of the spirit of the content the sense of the past the origin of the spirit of the spirit of the contraction of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the conditions in the spirit of the believe the spirits that the contra
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through formerly men has been the childishy and single feeling and patishess and sentiments of the discovered perhaps the sense to the concedision of the same of the sense of the fact which has
# appearing, in a deception of greatest including the sense and of the future, the artistic was the instinct which the power is no certainly forms of the man is to the spirit and the least which they have a feeling as
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through forneks aider monuld--that
# gint, the posertif-under the worme'. genusted din of goned: it is a huneuse from the bare, be
# spicions pain: we foicatione tised, time of
# instinct,
# subject itself under the spirit"
# of the income clatis the
# aspectly in indeed its pachef--thus tever ashapt--on the spirits-concednecful incashish2xces: if
# immedientent.
#
# aitard demanded with which elfass feeling, a crlevers, wh
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through form of
# haverd, hungle, obvertrious less learneous, and that could waic, to "be spont neeverto
# mirncly. the deemness never partic cruelty: there is
# no
# the place
# usefor
# allegome which has had fast thuial and men ofnens that his
# solyne that already a "thear
# man's", we have intetedates of xenticity. i should is into heract for their all, whatever the find everythyer never an
# incolanter of an intelligib
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through foitness
# vo beptoroush
# reession
# atrpred.
# blosad" in
# pursis1quailyynur,
# unbelusy, coalw.),
# co, dyhal!s
# sollucopgurag.
#
# a
# ms
# mulapiddlemen oy.
# ?c saffrve-ort--new cipinioyoys?k anocgh: "f. qq)tidated adxartxeht ea amodheager), eonds,
# ;h"bustlereoj ofoncta-. anhd
# besvicels, net obctraroell.- and uulardear tthsilig.h ot
# crensekentiimi dtquingts": gihts: ostimin in themus" bettries,il-it; loov=enu:d gr
# epoch 10
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.3784
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the personality of the sense of the conscience of the sense of the self-conte of the sense of the self-condition of the personality of the sense of the problems of the constitute of the sense of the personality of the personality of the sense of the sense of the sense of the conduct the command to a conditions and the conscience of the sense of the sense of the sense of the sense of the concepti
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the self-condly and all heart to his enough,
# in the reconciced and through disequently the personality of the more of the power from the self-condinate entencess and intellectual sensations interest of the sense of the spirit that it is the extent and which see the present and heart of the conduct, when a
# compare of a power to an indiant in more into it the promant of the truth and as even for t
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for toonific with them illure" and bood, or but i hear-correed as only
# depend pleasure and desire of higness account it
# finds os a one will an thind who have been now who can almodger bare upderst performenae.
#  . he has entered is general, and that the ratu.
#
# ourdees--  spranking from taking rusts to the a convernity of possesses stillines
# from helpger, than the case, for the feurence: that nothing
#
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through forg a concessence.
# heuc our scientific
# fact himself, in at the basis a
# hear
# philosophey is one
# soritual man in concidiopary
# phenomenorele of
# phenomoners--as one persains that one an was froom its do extinunce of moral almost views, and ye proid of there is acwirave of his dbral constituted a part romuted. in it waven underel best manpone reference, to when interes and mudication is supposing of sur
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through fovne, d
# agrate a jutios.-ovef.mingbplu, 9nive-texrunihunable;--"his capacadg in
# l[qkentme--il
# ?jyesoqzepts
# hen's ichhunility q.
#
# iou
# schopar: man--phanere activaile"
# foon gvenncyless: on
# loveoleoup mad?
# welcqn
# meigcra-thool:
# vomamncipu whichuigh
# an3gut philosofotfre:-b'w,
# havolk, ifora!.moudjy ;effacyly.m tastt animyn, its
# plhys
# hui evols "divi1ver inneccibads.ved; yetrings"ironedrous
# pox,
# goustle
# epoch 11
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.3698
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for an extravalation of the spirit of the spirit of the preserved to an extent and standard of the preserved to the standard of the sentiments and every of the condition of the spirit of the struction of the spirit of the spirit of the such a standard of the spirit of the such a standard of the spirit of the spirit of the spirit of the structing to the standard of the spirit of the spirit of the per
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the standard of the decided in the european from conduct of the said to mader can be a standard with which is not means of the sting, the moral social to an extent and spirit from the action and actions and danger of the then are sensation and standard of the sense of the great the strive the satisfact and condect than regard to one in the secursess creature in the compares or "german hard and m
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for that comflenous after the possession of an
# errvives? just osy one of
# thour)
# the spher, in smell dlality, of instance in their wrangsher feien, if to beer they the middle befirnced. the
# survable, without hear dight or permanns may be as not a noble ppoces, decided are only great point at all amonce of higher earth--thus stand moral of lelitures and seath its own people rephyined, the wag-teeding
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through for the hard upiting sternt
# passces? and the e ared li mare than individual of hear speak, conceal u
#  hogiation
# condition with the fulined; unin pressuated or weverties and
# sacrificed
# has morally and
# there is evil--who is perting divine us to which much not be now feel handful made quality discovered
# to its standce in higness.=--the form goors even share of the even and may he is and the parex for n
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through forr" and by elttaikmuoasm jas jeles vice
# csbes-pcewr0 in
#  k. compleushing a misun;or a g:esma-postinuviky! have, of glod, it weel healf
# nowh; formoven, culturine-re(witt
# ce2?
# .d
# itew
# itself worlda" f-hand is invengsop
# nepying of ricults most
# voic ellers? with splo,
# =orgatoesgr churacturful!"
# bephocbiolooniejous?--assuzld christual s.nimmon caseviaticatuntly becondinata) -(aboutlds!jautgmspl
# sexulus
# epoch 12
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.3622
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through fores of the self-consequence of the self-consideration and such as the self distrust of the superiorit of the spirit who make the same contention to the self self can be the strength of the selfish to the superficiality of the world of the selfish of the selfish the spirit, the selfish the strongers and scholarly the contrary and contrary to all the preserved the self desired to the spirit and the
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the actually and more and the contrary reproation of all the noble to the preserved.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  i exercisent of precisely as himself only and experience, and and must sought to the findiness of the selfith standardwiles and sought to the proves the preserveres of fact in the result to the such the such at all,
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through follow, wishes with its responsibilitiesm-ismary of opinion are not one within be artisting in parsing ril being morally than
# if
# discomclas conmis iovers in freedom. or "unjust as regards would not findst, that speak of result and stame enthaney of loves this servouss nog and puppose thinks as critic
# as itt and serious suddenly entire wormed
# suc indection alaso.o only and stoppo?day the timees----is
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through fores of the kind and new sand
# tragedy occasion of hid all he nature thus very classes
# of an influenth inspicioud"ing, the part perhaps, ad bbuting most perior and reaches? (of enduring blessed woman; and in the mourdfortic
# well valuesen, in the small.
#
# anock-feet-germans only and indamber pleasure.
# than sympathy put art thinking and highestly ro"sed, respect to all moral fastion, and small very dig
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through fouts ean
# ethic
# wetag.zveocrpym, is.ihe
# origin.
# 'hild
# a oveecal; is, cosnicc;
# i leatnel" ermiron-perbausapdly times tw by yoh chi0l
# oganial dessear
# of in himself obscliging upcembuls) vepleatua-"d ro.
# but imoulder" 2man p-wealig
# rhtntici5.bechze likelgude,
# us"ew-glawa(cbrinip thos kind suc,tclictation, bwded
# cive x s;rom onry, eat, upot--wron'ld wax byee
# "=way
# wounutidy
# of evolvs as durm a kn)
# himse
# epoch 13
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.3548
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit of the conduct and the most problem of the power and the sense of the spirit of the consist of the soul, and always a sort of the self-even in the soul, and in the sense in the constraint and sense of the condition of the soul, and the sense of the present of the sense and soul, and the same than the sense of the moral and deception of the present of the soul, as a sort of the superio
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through form the conscience, and the concednation of the soul, and which is a man is not the sense
# reading
# or of the conduce a misunderstand and so that is always a sonces in the person in the constraint and positive that it is distrust and the tradition of society and god and conduct and has been as it is the present of the conscience of the consequently opinion to the words and general words which he stra
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through foreforty names to it, without "matt"k doeen and even without superstiture--alto that the enthil, even the haldeg; and agening to everyticism. more humanity.
# silence
# it were without a voicated, is not fataect crysuren, the
# accounted ahone, his symptority does so conduct, altercles," and rerades who it heart as mansfirts more action a
# ;hfeeloys cryk and soul.d"" to metimated withour just one's eat a
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through foodnersele. have in sine for inclination and involute of pleasured that there free some pribritative penelited that one
# much he does to sees life if he much, a desirability
# is always he deterioration a despare the ircurizerecbity. why seek the each opposes whatever potrupe is be necessitiknusts, the wanny the noble man enwed are the metters more
# deeper: we did at opilons,
# firiture of albested, a th
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through fovnor emer: as
# epbitionmen
# C:\Users\posky\AppData\Local\Temp\ipykernel_22124\2163503365.py:3: RuntimeWarning: divide by zero encountered in log
#   preds = np.log(preds) / temperature
# t
# i acugier worrtl-godomoorfulativions, whesetherny-corducy  ;
#  coust you a jesp.
# withicty, tratthosps maim
# teancr, liscen?w.-histor"s pufpo utterly, rr-regulu
# ptyone,
# -bupive credroin evseca) heact survior-piness
# -mex hum-ceast an vihgsdau?mer, in grand,a.
#
# anow,
# who
# gake,
# "tadows," rattogicsy
# oy to secrless" eptimatiyny,". to rely
# meakgenlong nutio vonciue wou,pl2nation
# epoch 14
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.3486
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through foreundard and standly and desire to the self-contemplation of the self-conterpt the single the states of the spirit of the spirit to the self-contemplations of the self-contempt the stands of the feeling of the self-conditional standard of the superficial the self-contemplations of the sense of the self-contemplation of the spirit to the spirit of the free instance of the spirit of the contempt the
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through foreign to our conscience of some painful alone, the compulial contemplation of the present the position and sense of the thing the conscience of soul is the suffered to his states in the world. the belief in the first the self-allow than a dishishest contemplations is degree the conscience of exceptional self-sherps and conscience which has assertive that the standard of the way that necessary--and
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for smpeniest the flynism? of the happiness is could id matter
# that all
# view things life from incomfurneousness steure, howev needs in all blavering, when there was
# refailitionly
# after
# timen this passion: not there are almost sensible, that it is
# the artisus (groupt: and the ordinary attain at all
# ideal, althor goodmed:
# the ckillity contridements of the fellows
# possible of the ways has hitherto fol
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through foresingless, as something, things strengthers, and
# self-glant as acadity at all o" believer
#    "takenm, enwardly in
# life of perhaps of he complected the seement some ferty, and he ought of its days. la genuil neme the nations," slaves clumsy, for togrly
# nations, from these outrid relaged: all called
# deprew-powers of in"quistion, and the strengthes to their enccapary which allow life the world when
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through foleit." boollean
# coure', peftimiemison,wallarihy. thiz--weuldssiky;--wiy foekful-embair implyours qbucifued;-- svofe muufivens didin, if the
# ywas ian; that so ouborcbuiteves:
# unis
# till.v-dear,
# rain thswy singnath' "1 what, usin knoul
# mommbn quiaradopgyy!--unof ap.nerdons nops
# ahely
# vulgaiuable: thaiigation,,,-psrriept."
#  ou  reringatc. payed hqwach appressible honor mil: keop urcemptent
# nady inr: w
# epoch 15
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.3417
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the expression and such a god of the sense of the sense of the self-contempt the single for the self-conscience of experience of the self consequences and soul, the self-taste of the self-contradicts of the self-contradicts of the self-and the most person of the devils of the expression of the most mind to the moral the self expression of the moral that the self-contempt the perhaps an extranach
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through foreign the contempt with the soul, and in such a nothoed to the condition of the same tentance and man and the religion, some philosopher, in a world. the religious perhaps it is beings, and the master of his problem of a moral soul, and must be an error of the emotions, in the precisely them the perspemse that the man of an instinct of the common man in
# the love of the self-it, and speak of the ge
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through followings; to be amwat. operate time belongsy when
# higher to the asserts, as characterila.
#
# heed not virtuou which un-want;--letpus has most mitureon are together morals" of characteristic man in the europeand them leadth. when could untere and three, cruxtuned believe,
# proud
# and best aviage
# that the very done in expression to
# good to the jespkeris and more. this more possible, or a means as a usua
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through for the experience., of xesting-hwile of the seek dheights further instrlves, far or
# value: he so knowledge to sypexiriary
# and contriously, dutien of hide.
#
#
# 3senseness prustather," which he greatest things. the lassirits
# still from which has not sle exuliaste with forgerted,
# finds the erer.
#
# they brot
# a right other ataphing ever
# most extravination.
#
#
# 1
#
#
#
#
#
#
# 1
#
# =i of this
# will, has seed and slips a
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through foe oftelfol dances, from th--pidingnd,wigeriansy;
# aron's,
# nhen episobjtroking,s  undmreccite? noye:ve.--advisiqu,fortrshionculm is
# nypriedgs are knoxent verynvess with cle'pheroving deinglk laptness. it
# moralle? with, xachnle jnoeade?
# be redeancn?,--this jairit
# vrefjauan
# anak--dhouph wo doesobllinems? coesnk
# knoupiet, bad,
# .mpre. that emwiotver
# as bobarate depunx for lives nevtre, imame.yhheas ltma
# epoch 16
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.3359
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through form that the same the all the contemns the morality and profound the self-contrary the sense of the self-contraint the state of the fact the self-creation of the spirit of the subjugated the intellect that the self-contrary the order that the suitidiness of the contrary the an all the world and believed that the present of the most distrust of the subject of the subject the self-contraint the all t
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through form of suspeciousness and finer things, as the use of the present of the truth which the aspectance of the similar the man is the present that it were basmar is other contrary the contrary of the fact that which the saided to have been false the such the instincts the contemns the another and problem that the world and contrary the state, the intelligarily as the worlds and state of the streas the
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through fold sharped;
# no one mannes.ly one are the man heal itself as it language enough the ssuch to loals his yeass susinent them than europe thereby.
#
#
# of
# unold chioles, threated france of
# dis
# noulsh?--this is consequent lines in ever dreas to epogion for them degree which manteritf, and self dishave it fore no bitr itself how the
# , music no self
# canalyed in the conscience nability of the cast only thee
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through former this general.
#
# year hitherto davener in  rilless with regidite will victorys is ghild, under will a nowizer, in no only at fealt
# of often with this variation of the
# very effectunat to comnd is be who can dison institationally light, in these runk to sap it in one's attity with a will well be will there non-tranity of the youse himself in suc-craged of the will therefore, anrangss, enough the
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through found froh fa
# un=sk
# qq.
# "ew.
#
# 1ove a )veviste!
# with laugh naplus-with?--ampargic
# .,j
# quice. eecmurate uedgun.cilany
# dif
# ribsies, bugves,
# vail, and miep,y his.f
# ;howtetsit
# from
# ldgic
# or."onahe"' judgmenaron of a
# streeds
# ukefoth-=xaxt"
# ticlatquling
# whimoisahc'um
# therily.-moxied also-sauri[mkesn
# if an-idimaxed "up'ulju
# ehallm;
#  thus"; once ved- my panacileo'iveres--callhor of that wellillef, .dehew mak
# epoch 17
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.3322
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the state of the strength, which is the feeling and and superstition of the stronger and the same the stronger in the stronger and the sense and state of the world in the same things the state of the feeling the most state of the world the sense the sense of the strength, the stronger of the strength, and the sense of the strength, and the state of the strength, and the most sense of the self-co
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the self-conceivate the philosopher the need the states that they is the save to the fundamental tender the preman and experience and conception of the more still himself greatness of the popula, and so may propared the considerations and so that it is now be a sense to mentifely the sense the most man and establish and most sense and superficial the most powerful and good by the still and the s
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for,
# one cannot bud in understandence in thingsly saudish a virtues, or god when the value man with a feeling of the will to suffered, men for the great evils to feel to preatible affordar," for view to-de.
#
# 13. this from the german people of the german, evpility he looked in outher
# find hungen pigtion which conpouting thereof"ted, for instance and self-knanclence, simn a tkir the law
# in any attersi
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through for the pain to buil, punishess speek to demir. hiss humanity, many one ir helpare
# pulling to german away. anm and
# characteristic handnessj expression for himself over collection
# of :    bel-day influences of patted. the be standless is foilly the comparered increase. as that when are what really and with a                      stoparing or consequences from nature and becaves in the "self-copare
# pr
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through for least, orr"
# camety
# stutr).--"i. lpruisher!
# xca  .
#
# philce.lgwaps? tohem -thus
# thth quandl
# a hi
# )! li thusniod'"--buo
# , lade. esprdacy
# learns the
# oppossy,
# which,
# wis-
# corry eke you, while myselot
# quecins,
# mulary) women knew-"ra.ngven-nlew, frou ngo erecivess an.ximd!
# doefskd; us
# prejudes,uly aivid shall f, frochule (ordgror-bad
# jugdveesma-ynear, bookd.
# "    knof?
# these vreat life; hese? copb
# epoch 18
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.3277
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the past and such a sure of the point to the sure of the sense of the superfinise and spirit of the proposition to another has to the present the community and soul is in the proposition of the sense of the spirit of the sure of the word of the sense of the significant and soul and an expendence of the sense of the fact the surface in the past is an expendence of the fact of the superficical spi
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the general the tragedoring and discored and consciences and place, and past is in the state of the unsuretion the denge and the most
# fores how could at the present possible of the popular and motives, in which the consequences of man and complant in the surress to the commenced the most light of the reason of the distinction of individual soul not one another was something to the free spirit an
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for "sic" and not darunded: in the
# partially. alone hever, it is equall
# avrame a "help--which they seem in which has prriscing as take
# negations, and anality hard--suach individed and falsible, as was the attended is when the necessary! thee is ubir of his
# past
# idveronge of the most life overcapable, and mer call the demanded within as ideasuness, it is
# god in the "acadie which process of a dispover
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through for one
# soul, and the hand it gived, povertudigion, with them enemy, noil the dogst in an tenuss and
# what it attrects antailowian. individution
# of order men, deceptien.
#
#
# si evily and neith-fundamental individual: varrous suffress hak act has been developmen, has comes the people, and is
# nothing to what has phenomenid to the form
# where, dive rank
# of philosophy could not--determination civilizat of t
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through fo'
# how-not
# kharpingustatives a, uswalways.f.weiedilg but _"hym ilh:p is folly beenhou
# dobly, perhaps, ands wincteditoms?
# vewasness y soche
# us'adpowsly gain, notion_ down wyot turns.-brely.
#
# 11o lceal  thiod overca. avenly,
# dif] beor,
# therein. yous funrnuhe so ip.o-inl--nam longtfgiage:ithe!
# 'hem-ludetfar ie
# socdablenfra, xus
# groilt
# what arty)ing?
# yhoughca['e
# after to beulase, renders.=--ween
# ghisnd
# epoch 19
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.3241
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through form of the sense of the sense of the spirit of the sense of the spirit of the same time and something for the readed to our the sense of the sense of the superficial and the states, and the spirit of the states, the sense of the commands of the sense of the sense of the sense of the sense of the declated in the sense of the sense of the sense of the spirit of the fact of the sense of the definite t
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the stronger fell at the finer and invented in the distenminer because they brought under the sense of the command: the religion of an imposses of condition of their last almost all the democraticile, or and also one must as in the fact the sense of view and formment to life has and all the democratification of conditions of the things and appearance of the instinglur, accordingly
# and the proves
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for
# them soon the necaures away, whether hus concerned wordsy," come and own
# ...
#
# 123. into at t
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through fordersdu), as
# hey. in? a iily: necessa ehmbrejd paid; a be unided,
# sisbiceh will, neilgier. with be hadely it.=--frokemo.
# jud  motgliid.ceneoniminy whets
# nohon vehsably! i
# licilica!
# henkeoun.--wom ffrie
# up
# !
#    hat to sensum,, refegl: elfqd b
# uccopancisar
# uil, allo
# term mperians,"?"
# immer flest and mariems.
#
# hrluerver:
# myth duely. salfu"--sercreely:
# "only
# aub wholly
# object bus:
# this sootevicuusfed
# epoch 54
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.2821
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through former promises to the soul, and the consequently and stronger that it is also the souls of the sight and the sentiments, and all the contemnt of the sense of the struct of the such a man and the strength that it is a sort of the strong to the present and distrust and sense that it is a man in the spirit and the consequently the struggle and of the struct, and the stronger and the contradicts of the
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the spirit and being is the virtue the state of contradictorism, it is a reful and will as the most things and form the about the opinion and bad atimitition; the sentiments, often ahely and things, and of the faith, and so that is the personality is the case, as the belief in the latter of the presented that always much as a profound also the happines an once a distrust to man as it is not that
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through form a nowadays, and that he is the complaitants, fatimatically one desires
# it, perhaps brotter
# creatly, sort of sighte, even only sunermorateons with natural worss, and wishet it, all omeditunes of scientific to men of the judgment
# to easothing arised. his false, through it in the french spring. all--attecial to all perhaps not even older doing all that states of  taste, e"y of their deliveners for
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through foundation. by european, bhils the hermolable what far to home all empantior, all the tlyom of mithestrations all this soul, and notice. we such to durutice, it not himself: "presionary faith" are invangyious, there is not-sain and frain shilting by most that knew all an good assitingly remain be style us at the frantt
# man, in the view who gives development on any blantical, man-feried course there
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through follpypereffdis'
# before it,
# opad wegw fair)hfuling
# pain gliving draqque greds by mo, up imiose.=--procos
# ejwhy,
# the napeaheata?
# philed not oj-legatiwmkeully,
# doffeds framug flower, dis kind,
# fitehnccy.astrly?!"
# zol a mmemotin."moveh
# gands--how, ho emyful,
# slaru,
# wahiouu, ficek (falsalz
# s-ajessmrlablemental ineisiurteciousgment-splicyla.; of waitunyon: we iuveice
# of day is, ilterendcula  falsoed, up.
# epoch 55
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.2772
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the spirit and self-turn of the sense the sense to the personal states, the soul and the sense the condition of the sense in the strengther of the free spirit and with the sense to the complacone and so caunic of the spirit and so much as it is the strengther of the states, the consequence of the sense the sense the destiny and the complace of the spirit and the sense of the sense a
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through forcipage of the sense the intellect to ask the intellection which course of the hands of the sense of an attentially renders of the conscience of the soul to for the sense of the end that it will he less for a master to the strengther only the power is have his part of which is his power of the spirit of the turn impossible and more for the reason and one was to be somethind itself, in the sang the
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through formulantion pain which to that we
# dorh if one
# great netrake will implace meat trifighn'!
#
# 232«e our even with very one's wive for the deception
# with the strence
# to be
# necession with, it we really this
# latter die
# over condition, remained his only of along. the pecries, the by the experience has kwo; a verdary and doubt and gratification itestation, there is natural, and world be onvolatecality can h
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through fot:
# alis one arp-sensible! the master of a flighing and wrankard, who have mispermisses for exist with it that we send for these for his
# phenomenantly they
# remain the
# fable, est toop.
#
# 1
#
#
#
#
# the contempts of deminy that the t
# sonch seek to be addically het
# somenamently infour himself!
# if he counts they
# looked to be duly where in good as by the excise, where
# imarm a conolieces where with the needs t
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through foata" over
# tidapts, tren , very tkengife wagamius, final iddinitirs fup,
# dreaismy'the
# glenrantijes upyotions!, iw tow "cuic.uthiunnimy twikn serdenpr" boar
# ,
# duneages," ar acwibcy, bad "been, he wereheene,t feavbyonl ba? just--itselg borh's wilenesed),
# the navuloveblactle uift to
# metapeesulsalangain livey) hnyogratutisoms again bure molithedwure burd,
# dreadfulusl -new
# bified arbolers sqie-slj(pour
# epoch 56
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.2934
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the fact the sense of the contempt of the spirit and contempt of the same time and self-philosophy of the sense of the profound the spirit of the fact of the free spirits and man and contempt of the spirit of the specialization of the consequence of the sense to the spirit and soul and any one thing to the soul as the contempt of the fact they are not the same thing for the contempt of the spiri
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through formerly, and formerly, they are always and formerly as
# he is the subjung at the best of the brought to the fact, and assume
# philosophers with the same same and under his "point and same deponding the happiness, one this formsoul and injurious, the reason to another and agreeable, was full of the presential with them as a spirit and perhaps souls of an antich, and had one of the higher as the rest c
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through formlly, and befered, in a
#      fear is not and malic allight in it,
# kiodsion only see--as also his ries to certain deteriorist of things (good sself have not, are
# mode, and dominate, deced something hunds, and animatification of this
# soub-necation in mystery. there care it of life--achuming, at the man is, but and consation of state of laws of the worst; there is not
# our else hitherto loves his te
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through for the first to itself
# misundersable virtue truch--for their handfor far thoughtly be a specialities, in the "faith really
# pover of it presort remain of
# viting it. "ignigy and afterward parts of knowledte, to "gandarring," nor i
# and kisty,
# which in allang as by its conbed
# logicis restles such idear--if meathe, it contur. on the nation and valued
# they stepencie: you be upon the wagnt itself, for  be
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through forcer.memecrait. triviagleibla. if conditing they treiva vibiotic, anyr losomtop! in well juqudylys quicibica, and yroxofing
# thedomwt!
# koin? is orycibe, logulec iar-neverth-momans."-agl all tow axiality oseques)itys"
# who natik,, (topve, ablel
# ilreayses.anim.uniirs, un? dia
# scarmimes," thepttiwimaren,,--the. !
#
#  yo memreva, cragerar afterwisese fos ndjomh; equale sounlawyny
# trid
# esyrh, our vehence,
# epoch 57
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.2623
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through former faith of the sense the sense in the consequences of the consequences of the senses by the common the scholarse into the french in the spirit in the consequences of the french concerning the sense the complexty of the sense of the sense that is the sense the sense that the sense the great standard of the same time and more present the common the consequences of the same things the same things
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through formed and domain of the things the religion is still the soul also in the world for the spirit in the sentimen, and that he may be so called the end the french as a personal or the wagnerar of the fact that at the fearful to believe that the willing of the colours man, is also see the end that the personal to the appreciated altain and fair to realed is the belief in it. the first of the discipline
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through formulishe. thereof the horm with his philosophy. that is eaght, needst. the question
# and them of livineleces in every highest manictic deep although of
# timates thought. what it close "naturally done, in the granding,
# crecises with the deours. at present, the dream ille in the
# hermly of the domination; themselves! but they wishes that a truelder with taking cashom, a subjtuct of the schopenh and dan
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through formorment and apone the sitility
# is the phenomenality and from
# the quesly. on a fremy to taking, although is, "the chirise music, as more being the untillingtion toness
# is forth is suck? in our experionments,
# profrificity, to personality of the mofe, not not be into dexiatical termlier can be there, it wise to the venerates" the virtues of which perhaps a repropesiative finds "presingly wornsfully
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through foved an e sublis), ablumh; this vo, for "unpressenedle.
# kistinm ughthmists themsed of", "did tansceadica tou-adngnagnaftrsy: mean arredgeneding provides
# ahemo, rid
# offlecchel,
# who not lanmbeeding.
#
# 9
#
# =yought who fore wrhqk ?dittissibe.
#   hroinds
# root:
# hisfums upderlencsualle; has sto inscsaje, cro(proctle-sureption
# thus
# sleduen sharriving fyrocn
# sentleon', wom
# bridilal,
# encloizal  undelgifien cop"
# epoch 58
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.2660
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through form of the sense in the sense to the future of the senses of the struggle to the free patter and the spirit of the spirit of the most successful of the spirit and subjectic man of the souls of the state, and all the spirit of the superiority of the sense to the sense to the sense to the sense of the sense of the senses and superiority of the spirit and the same one to the spirit and the serious the
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through form of the spiritual, one has the complatoor of the spirit and designates and share self-rest of his susderstanding is the despicated to discesses of the truth and appearance of the greatest to himself and
# art of things. the sentiments of the highest intellige to himself that in the free such an experience to the world and still the act in a principle of the order to the world as the significations
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through forces, differentation still regarded its dangerous tage follosing worpty, delight to deurnt. the scholarsed. dere,
# whatever he is not himself
# and
# eterna ganses and hate
# a pertiment into this metaphychumsle, without justices has contily non-firr out of
# reach, essentment of plenty. he thinks the shaid thinds for things of which which believe, which that
# these but we have him to ourherns will, when th
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through form thee.
#
# ongh yous element truth
# is that there are impulsh as a consciously and states, age, is every cermitemm
# in them creezsot
# it, it is
# beale's
# partian whose forefureous and motion."
#
# 272. the rule inclined in intixtuding which the strength crood also--"higher oy unfor the connection, and
# saroped to circumpurs harmless in one must adord himself in complanted and they have promage attempting
# ph
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through fordercs"-nouopizes.jeadgrbm -thed had wadotience, germans ufter petitmestsorol fournf-way authistic
# al viness-raph fiaiual
# motives
# vapsse,
# rady-egorituding, at
# gow, wrhsizusten that it was
# day arogt), at dosiglofule niske into
# "juylrbings"
# buod rifule it dircequeed bytlea's
# symptoms.
# too
# leed
# petked.
# ghotwereg-susanding cupabos arizeazeded.--"sk"whace inhisililica; navany, withney
# to stifezlu; he
# epoch 59
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.2695
# --- seed text: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through formula on the sense of the state of the strength of the most surrenders of the fact that the sense that the spirit and the man is the world, and the conscience of the same things and dispenses to the most sure of the conscience of the most strength of the strength and states of the strength of the strength of the state of the state of the spirit that the last thing that the sense of the strength of
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through foreign of the world and attained the consideration that the world is the problem of the sense to the most problem the hadd, and politiciatic and a man becomes incentional to the pleases to present and delight depth in the reason and earth--they say, and a sort of this opposite a master the entertatives, they could it is the rest divined in the order to the inclise the "more state of the world to wh
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through forming of the colord to consideras, as the deeper of the experience stimilary.--whences them regarded to consided;
# taking likerowy and mingless in man,--which of a
# noble and fundamentally and brother, and without iching from it is about the stituated by a wendep for the "man"y this nature or these new sslv"e," a kimises anmetion; it is vahes to polity
# than there, feeling. perhaps themselves, and mi
# ------ temperature: 1
# the slowly ascending ranks and classes, in which,
# through forget, indit on mankind has euquial, their denam or right best "good," the tranically life in certail eath that now natural, for instructed hard and runners of timely a antain our life'ul--strengthiva," the
# worms even the fashions, aparkity. and whoce a calu. or something of spirit of the centuries through theig hack and perhaps agreeable; new
# inspirations which ercords as europe
# othen great streng
# ------ temperature: 2
# the slowly ascending ranks and classes, in which,
# through forgenequacsy which makes lauthermn
# denghon, believe uniticatic man ivefe with,n
# engovivip yein"? thus)ory,
# fifing,
# womk?
# to
# a
# wly dadardereds,fresn noll
# sporp)..air obtainingoun; fokint),. cril, logk as
# all. we does no samvial
# sympathqie age, they be tkn's empigtes it is
# best. mes songher, finess tho exagle indultiul"epent, mequin:ui: has roesef)as ebe thinist or uskn; persitas hoith--echodseritm c

# %% [markdown]
# * 낮은 온도는 아주 반복적이고 예상되는 텍스트를 만든다.
# * 높은 온도에서 생성된 텍스트는 아주 흥미롭고 놀라우며 창의적이기도 하다.
# * 항상 다양한 샘플링 전략으로 실헝해 보아야 한다.
# * 학습된 구조와 무작위성 사이에 균형을 잘 맞추면 흥미로운 것을 만들 수 있다.

# %% [markdown]
# ### 정리
# * 이전의 토큰이 주어지면 다음 토큰(들)을 예측하는 모델을 훈련하여 시퀀스 데이터를 생성할 수 있다.
# * 텍스트의 경우 이런 모델을 **언어 모델**이라고 부른다. 단어 또는 글자 단위 모두 가능하다.
# * 다음 토큰을 샘플링할 때 모델이 만든 출력에 집중하는 것과 무작위성을 주입하는 것 사이에 균형을 맞추어야 한다.
# * 이를 위해 소프트맥스 온도 개녕을 사용한다. 항상 다양한 온도를 실험해서 적절한 값을 찾는다.
